# %% [markdown]
# **Machine Learning Algorithm on Covid19data dataset**

# %%
import numpy as npd
import matplotlib.pyplot as plt
import plotly.graph_objects as go

# %%
import pandas as pd
df = pd.read_csv('/content/country_wise_latest.csv');
df

# %%
df.info()

# %%
df.shape

# %%
df.head()

# %%
#test plotting
plt.figure(1,figsize=(5,45))
plt.scatter(df['Confirmed'],df['Country/Region'])

# %%
import geopandas as gpd
df_world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
print(f"{type(df_world)}, {df_world.geometry.name}")
print(df_world.head())
print(df_world.geometry.geom_type.value_counts())

# %%
max_cases = df["Confirmed"].max()
max_cases

# %%
df_world.plot()

# %%
df_world_merged = df_world.merge(df, how="left", left_on=['name'], right_on=['Country/Region'])
df_world_merged

# %%
df_world_merged.plot(figsize=(15,10))

# %%
df_world_merged.plot(column="Confirmed",cmap='OrRd', legend=True, legend_kwds={"label": "Confirmed cases", "orientation": "horizontal"},figsize=(20,10))

# %%
df_world_merged.plot(column="Deaths",cmap='Blues', legend=True, legend_kwds={"label": "Deaths", "orientation": "horizontal"},figsize=(20,10))

# %%
df_world_merged.plot(column="Recovered",cmap='Purples', legend=True, legend_kwds={"label": "Recovered", "orientation": "horizontal"},figsize=(20,10))

# %%
df_world_merged.plot(column="Active",cmap='Greens', legend=True, legend_kwds={"label": "Active cases", "orientation": "horizontal"},figsize=(20,10))

# %%
df_world_merged.plot(column="Confirmed last week",cmap='YlOrRd', legend=True, legend_kwds={"label": "Confirmed last week cases", "orientation": "horizontal"},figsize=(20,10))

# %%
df_world_merged.plot(column="1 week change",cmap='PuRd', legend=True, legend_kwds={"label": "Changes in cases in past 1 week", "orientation": "horizontal"},figsize=(20,10))

# %%
df_world_merged.plot(column="1 week % increase",cmap='YlGnBu', legend=True, legend_kwds={"label": "Percentage Increase in 1 week", "orientation": "horizontal"},figsize=(20,10))

# %%
df_world_merged.plot(column="New cases",cmap='BuGn', legend=True, legend_kwds={"label": "New cases after last report", "orientation": "horizontal"},figsize=(20,10))

# %%
df_world_merged.plot(column="New deaths",cmap='gist_yarg', legend=True, legend_kwds={"label": "New deaths after last report", "orientation": "horizontal"},figsize=(20,10))

# %%
df_world_merged.plot(column="New recovered",cmap='Oranges', legend=True, legend_kwds={"label": "New recovered after last report", "orientation": "horizontal"},figsize=(20,10))

# %%
df_world_merged.plot(column="Deaths / 100 Cases",cmap='YlGn', legend=True, legend_kwds={"label": "Deaths per 100 cases", "orientation": "horizontal"},figsize=(20,10))

# %%
df_world_merged.plot(column="Recovered / 100 Cases",cmap='YlGn', legend=True, legend_kwds={"label": "Recovered per 100 cases", "orientation": "horizontal"},figsize=(20,10))

# %%
df_world_merged.plot(column="Deaths / 100 Recovered",cmap='YlGn', legend=True, legend_kwds={"label": "Deaths pre 100 cases", "orientation": "horizontal"},figsize=(20,10))
