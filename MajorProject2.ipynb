# %% [markdown]
# **Exploratory Data Analysis**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('/content/employee_data.csv')
df

# %%
df.head()
# Out:
#    Unnamed: 0  id groups  age  healthy_eating  active_lifestyle  salary
# 0           0   0      A   36               5                 5    2297
# 1           1   1      A   55               3                 5    1134
# 2           2   2      A   61               8                 1    4969
# 3           3   3      O   29               3                 6     902
# 4           4   4      O   34               6                 2    3574

# %%
df.info() #all the data enteries are non-null constraints

# %%
df.shape

# %%
total=df.isnull().sum().sort_values(ascending=False)
percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total,percent],axis=1, keys=['Total','Percent'])
missing_data.head()

# %%
df = df.drop(missing_data[missing_data['Total'] > 1 ].index,1)
df = df.drop(df.loc[df['salary'].isnull()].index)
df.isnull().sum().max()

# %%
sns.displot(df['active_lifestyle'])

# %%
sns.displot(df['age'])

# %%
sns.displot(df['groups'])

# %%
sns.displot(df['healthy_eating'])

# %%
sns.displot(df['salary'])

# %%
df.plot(figsize=(20,20))

# %%
sns.scatterplot(x=df['age'],y=df['salary'])

# %%
sns.jointplot(x=df['active_lifestyle'], y=df['groups'])

# %%
sns.jointplot(x=df['salary'], y=df['groups'])

# %%
"skewness : %f" % df['active_lifestyle'].skew()

# %%
cond_plot = sns.FacetGrid(data=df, col='age', hue='id', col_wrap=4)
cond_plot.map(sns.scatterplot, 'groups', 'active_lifestyle');

# %%
sorted_nb = df.groupby(['age'])['active_lifestyle'].median().sort_values()
sns.boxplot(x=df['age'], y=df['healthy_eating'], order=list(sorted_nb.index))

# %%
plt.stackplot(df['id'],df['age'])
